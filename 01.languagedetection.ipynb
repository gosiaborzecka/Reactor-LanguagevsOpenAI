# %% [markdown]
# # Language Detection

# %%
documents = [
    {
        "id": "1",
        # English
        "text": "Artificial Intelligence: Bridging gaps and enriching lives. It's more than just technology; it's a helping hand for humanity, unlocking new possibilities and offering solutions that once seemed impossible."
    },
    {
        "id": "2",
        # Spanish (Español):
        "text": "Inteligencia Artificial: Cerrando brechas y enriqueciendo vidas. Es más que tecnología; es una mano amiga para la humanidad, desbloqueando nuevas posibilidades y ofreciendo soluciones que antes parecían imposibles."
    },
    {
        "id": "3",
        # French (Français):
        "text": "Intelligence Artificielle : Comblant les lacunes et enrichissant les vies. Ce n'est pas seulement une technologie ; c'est une aide pour l'humanité, ouvrant de nouvelles possibilités et offrant des solutions autrefois inimaginables."
    },
    {
        "id": "4",
        # German (Deutsch):
        "text": "Künstliche Intelligenz: Lücken schließen und Leben bereichern. Es ist mehr als nur Technologie; es ist eine helfende Hand für die Menschheit, die neue Möglichkeiten eröffnet und Lösungen bietet, die einst unmöglich schienen."
    },
    {
        "id": "5",
        # Italian (Italiano):
        "text": "Intelligenza Artificiale: Colmare i divari e arricchire le vite. È più che tecnologia; è una mano amica per l'umanità, sbloccando nuove possibilità e offrendo soluzioni che una volta sembravano impossibili."
    },
    {
        "id": "6",
        # Portuguese (Português):
        "text": "Inteligência Artificial: Preenchendo lacunas e enriquecendo vidas. É mais do que apenas tecnologia; é uma mão amiga para a humanidade, desbloqueando novas possibilidades e oferecendo soluções que antes pareciam impossíveis."
    },
    {
        "id": "7",
        # Russian (Русский):
        "text": "Искусственный интеллект: Преодоление разрывов и обогащение жизни. Это больше, чем просто технология; это помощь человечеству, открывающая новые возможности и предлагающая решения, которые когда-то казались невозможными."
    },
    {
        "id": "8",
        # Chinese Simplified (简体中文):
        "text": "人工智能：弥合差距，丰富生活。它不仅仅是技术；它是人类的援助之手，解锁新的可能性，提供曾经似乎不可能的解决方案。"
    },
    {
        "id": "9",
        # Japanese (日本語):
        "text": "人工知能：ギャップを埋め、生活を豊かにする。それは単なる技術以上のものであり、新たな可能性を解き放ち、かつて不可能と思われた解決策を提供する人類への支援の手です。"
    },
    {
        "id": "10",
        # Korean (한국어):
        "text": "인공 지능: 격차를 메우고 삶을 풍요롭게 함. 단순한 기술을 넘어서 인류에게 도움의 손길을 제공하며, 한때 불가능해 보였던 해결책을 제시하고 새로운 가능성을 열어줍니다."
    },
    {
        "id": "11",
        # Arabic (العربية):
        "text": "الذكاء الاصطناعي: يسد الفجوات ويثري الحياة. إنه أكثر من مجرد تكنولوجيا؛ إنه يد مساعدة للإنسانية، يفتح آفاقًا جديدة ويقدم حلولاً كانت تبدو في يوم من الأيام مستحيلة."
    },
    {
        "id": "12",
        # Hindi (हिन्दी):
        "text": "कृत्रिम बुद्धिमत्ता: अंतरालों को पाटना और जीवन को समृद्ध बनाना। यह केवल तकनीक से अधिक है; यह मानवता के लिए सहायक हाथ है, नई संभावनाओं को खोलने और ऐसे समाधान प्रदान करने वाला है जो कभी असंभव प्रतीत होते थे।"
    },
    {
        "id": "13",
        # Bengali (বাংলা):
        "text": "কৃত্রিম বুদ্ধিমত্তা: ফাঁক ভরাট করা এবং জীবনকে সমৃদ্ধ করা। এটি শুধুমাত্র প্রযুক্তি নয়; এটি মানবতার জন্য একটি সাহায্যকারী হাত, নতুন সম্ভাবনা উন্মোচন করে এবং এমন সমাধান প্রদান করে যা একসময় অসম্ভব বলে মনে হত।"
    },
    {
        "id": "14",
        # Polish (Polski):
        "text": "Sztuczna Inteligencja: Łączenie przepaści i wzbogacanie życia. To więcej niż tylko technologia; to pomocna dłoń dla ludzkości, otwierająca nowe możliwości i oferująca rozwiązania, które kiedyś wydawały się niemożliwe."
    },
    {
        "id": "15",
        # Turkish (Türkçe):
        "text": "Yapay Zeka: Boşlukları doldurmak ve hayatları zenginleştirmek. Bu, sadece bir teknolojiden daha fazlasıdır; insanlık için bir yardım eli, yeni olanaklar sunan ve bir zamanlar imkansız görünen çözümler sunan bir yardım eli."
    },
    {
        "id": "16",
        # Dutch (Nederlands):
        "text": "Kunstmatige Intelligentie: Kloven overbruggen en levens verrijken. Het is meer dan alleen technologie; het is een helpende hand voor de mensheid, het ontsluiten van nieuwe mogelijkheden en het bieden van oplossingen die ooit onmogelijk leken."
    },
    {
        "id": "17",
        # Swedish (Svenska):
        "text": "Artificiell intelligens: Överbryggar klyftor och berikar liv. Det är mer än bara teknologi; det är en hjälpande hand för mänskligheten, som öppnar upp nya möjligheter och erbjuder lösningar som en gång verkade omöjliga."
    },
    {
        "id": "18",
        # Danish (Dansk):
        "text": "Kunstig intelligens: Overvinder kløfter og beriger liv. Det er mere end blot teknologi; det er en hjælpende hånd til menneskeheden, der åbner nye muligheder og tilbyder løsninger, der engang syntes umulige."
    },
    {
        "id": "19",
        # Finnish (Suomi):
        "text": "Tekoäly: Kuilujen ylittäminen ja elämän rikastuttaminen. Se on enemmän kuin pelkkää teknologiaa; se on auttava käsi ihmiskunnalle, avaten uusia mahdollisuuksia ja tarjoten ratkaisuja, jotka aikaisemmin näyttivät mahdottomilta."
    },
    {
        "id": "20",
        # Norwegian (Norsk):
        "text": "Kunstig intelligens: Brobygging og livsberikelse. Det er mer enn bare teknologi; det er en hjelpende hånd for menneskeheten, som låser opp nye muligheter og tilbyr løsninger som en gang virket umulige."
    },
    {
        "id": "21",
        # Greek (Ελληνικά):
        "text": "Τεχνητή Νοημοσύνη: Γεφυρώνοντας τα χάσματα και εμπλουτίζοντας τις ζωές. Δεν είναι απλώς τεχνολογία· είναι μια βοηθητική χείρα για την ανθρωπότητα, ξεκλειδώνοντας νέες δυνατότητες και προσφέροντας λύσεις που κάποτε φαίνονταν αδύνατες."
    },
    {
        "id": "22",
        # Czech (Čeština):
        "text": "Umělá inteligence: Překonávání mezer a obohacování životů. To je více než jen technologie; je to pomocná ruka pro lidstvo, odemykající nové možnosti a nabízející řešení, která se kdysi zdála nemožná."
    },
    {
        "id": "23",
        # Romanian (Română):
        "text": "Inteligența Artificială: Punte între goluri și îmbogățirea vieții. Este mai mult decât tehnologie; este o mână de ajutor pentru umanitate, deblocând noi posibilități și oferind soluții care odinioară păreau imposibile."
    },
    {
        "id": "24",
        # Hungarian (Magyar):
        "text": "Mesterséges Intelligencia: Űrök áthidalása és életek gazdagítása. Ez több mint csak technológia; ez az emberiség segítő keze, új lehetőségeket nyitva meg és olyan megoldásokat kínálva, amelyek korábban lehetetlennek tűntek."
    },  
    {
        "id": "25",
        # Slovak (Slovenský):
        "text": "Umelá inteligencia: Preklenovanie medzier a obohacovanie životov. Je to viac než len technológia; je to pomocná ruka pre ľudstvo, odomykajúca nové možnosti a ponúkajúca riešenia, ktoré kedysi považovali za nemožné."
    },
    {
        "id": "26",
        # Hebrew (עברית):
        "text": "בינה מלאכותית: מגשרת פערים ומעשירה חיים. זהו יותר מטכנולוגיה; זו יד עוזרת לאנושות, פותחת אפשרויות חדשות ומציעה פתרונות שפעם נראו בלתי אפשריים."
    },
    {
        "id": "27",
        # None
        "text": ":) :( :D"
    },
    {
        "id": "28",
        # Multiple languages
        "text": """Artificial Intelligence has the power to redefine our lives, making everyday tasks easier and more efficient. 
                Con la capacidad de analizar grandes cantidades de datos, la IA puede identificar tendencias y patrones invisibles para el ojo humano. 
                De plus, elle permet une personnalisation sans précédent des services en ligne, améliorant ainsi l'expérience utilisateur.
                Nonostante questi benefici, è fondamentale considerare le implicazioni etiche dell'automazione e della sorveglianza.
                Die Gesellschaft muss sich auf den Wandel vorbereiten und Strategien entwickeln, um sicherzustellen, dass alle von dieser Technologie profitieren.
                Finalmente, a inteligência artificial promete não só inovar, mas também inspirar novas gerações a imaginar o futuro."""
    }
    
]

# %%
language_should_be = [ "English", "Spanish", "French", "German", "Italian", "Portuguese", "Russian", "Chinese Simplified", "Japanese", "Korean", "Arabic", "Hindi", "Bengali", "Polish", "Turkish", "Dutch", "Swedish", "Danish", "Finnish", "Norwegian", "Greek", "Czech", "Romanian", "Hungarian", "Slovak", "Hebrew", "None", "Multiple" ]
language_should_be_original = ["English", "Español", "Français", "Deutsch", "Italiano", "Português", "Русский", "简体中文", "日本語", "한국어", "العربية", "हिन्दी", "বাংলা", "Polski", "Türkçe", "Nederlands", "Svenska", "Dansk", "Suomi", "Norsk", "Ελληνικά", "Čeština", "Română", "Magyar", "Slovenský", "עברית", "None", "Multiple"]
language_azure = []
language_openai = []

# %%
key = "{AzureLanguageKey}"
endpoint = "{AzureLanguageEndpoint}"

from azure.ai.textanalytics import TextAnalyticsClient
from azure.core.credentials import AzureKeyCredential

# Authenticate the client using your key and endpoint 
def authenticate_client():
    ta_credential = AzureKeyCredential(key)
    text_analytics_client = TextAnalyticsClient(
            endpoint=endpoint, 
            credential=ta_credential)
    return text_analytics_client

client = authenticate_client()

# Example method for detecting the language of text
def language_detection_example(client):
    try:
        response = client.detect_language(documents = documents)
        for document in response:
            print("Language: ", document.primary_language.name)
            language_azure.append(document.primary_language.name)

    except Exception as err:
        print("Encountered exception. {}".format(err))
language_detection_example(client)
# Out:
# Language:  English
# Language:  Spanish
# Language:  French
# Language:  German
# Language:  Italian
# Language:  Portuguese
# Language:  Russian
# Language:  Chinese_Simplified
# Language:  Japanese
# Language:  Korean
# Language:  Arabic
# Language:  Hindi
# Language:  Bengali
# Language:  Polish
# Language:  Turkish
# Language:  Dutch
# Language:  Swedish
# Language:  Danish
# Language:  Finnish
# Language:  Norwegian
# Language:  Greek
# Language:  Czech
# Language:  Romanian
# Language:  Hungarian
# Language:  Slovak
# Language:  Hebrew
# Language:  (Unknown)
# Language:  English

# %%
from openai import OpenAI

client = OpenAI(
    # defaults to os.environ.get("OPENAI_API_KEY")
    api_key="{OpenAIAPIKey}",
)


for document in documents:

    completion = client.chat.completions.create(
        model="gpt-4",
        messages = [
            {"role": "system", "content": "You are an AI language model trained to detect language in the text."},
            {"role": "user", "content": f"Detect the langugae in the text. Return only a single world of the language name: {document}"}
        ]
    )
    language_openai.append(completion.choices[0].message.content)
    print(document)
    print(completion.choices[0].message.content)
    print("***")
# Out:
# {'id': '1', 'text': "Artificial Intelligence: Bridging gaps and enriching lives. It's more than just technology; it's a helping hand for humanity, unlocking new possibilities and offering solutions that once seemed impossible."}
# English
# ***
# {'id': '2', 'text': 'Inteligencia Artificial: Cerrando brechas y enriqueciendo vidas. Es más que tecnología; es una mano amiga para la humanidad, desbloqueando nuevas posibilidades y ofreciendo soluciones que antes parecían imposibles.'}
# Spanish
# ***
# {'id': '3', 'text': "Intelligence Artificielle : Comblant les lacunes et enrichissant les vies. Ce n'est pas seulement une technologie ; c'est une aide pour l'humanité, ouvrant de nouvelles possibilités et offrant des solutions autrefois inimaginables."}
# French
# ***
# ...

# %%
import pandas as pd
# Compare Language vs Open AI

# Create a dictionary with the variables
data = {'Should be:': language_should_be, 'Original': language_should_be_original, 'Azure': language_azure, 'OpenAI': language_openai}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# Display the DataFrame
df
# Out:
#             Should be:    Original               Azure
# 0              English     English             English  \
# 1              Spanish     Español             Spanish
# 2               French    Français              French
# 3               German     Deutsch              German
# 4              Italian    Italiano             Italian
# 5           Portuguese   Português          Portuguese
# 6              Russian     Русский             Russian
# 7   Chinese Simplified        简体中文  Chinese_Simplified
# 8             Japanese         日本語            Japanese
# 9               Korean         한국어              Korean
# 10              Arabic     العربية              Arabic
# 11               Hindi      हिन्दी               Hindi
# 12             Bengali       বাংলা             Bengali
# 13              Polish      Polski              Polish
# 14             Turkish      Türkçe             Turkish
# 15               Dutch  Nederlands               Dutch
# ...
